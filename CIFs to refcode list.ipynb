# %%
import os

# %%
path = "C://Users//Admin//Downloads//CoRe_Large_MOFs//CoRe_Large_MOFs"
dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['abadug_P1.cif', 'abedeu_P1_H.cif', 'abelom01_P1.cif', 'abexen_P1_charged.cif', 'acemee_P1_charged.cif', 'acenif_P1.cif', 'aciboe_P1_H.cif', 'acipip_P1.cif', 'acodon_P1_charged_H.cif', 'acolub_P1.cif', 'acufek_P1_H.cif', 'acuruo_P1.cif', 'adabak01_P1_H.cif', 'adasij_P1_H.cif', 'adatac_P1_H.cif', 'adatik_P1_H.cif', 'adegey_P1_charged.cif', 'adipai_P1_charged.cif', 'adujer_P1.cif', 'aduwon_P1_charged_H.cif', 'afadan_P1_charged.cif', 'afitit_P1.cif', 'afukap_P1.cif', 'agofej_P1_charged_H.cif', 'agovid_P1_charged.cif', 'ahafar_P1.cif', 'aheqah_P1_H.cif', 'ahujev_P1.cif', 'ajakon_P1_H.cif', 'akayiv_P1.cif', 'akekin_P1.cif', 'akojao_P1.cif', 'alahus_P1_H.cif', 'alajop01_P1_H.cif', 'alecay_P1_charged.cif', 'alejei_P1_H.cif', 'alejim_P1_H.cif', 'alicii_P1_charged.cif', 'alixid_P1_charged.cif', 'aludix_P1_H.cif', 'amilue_P1.cif', 'anugia_P1_H.cif', 'anugum_P1.cif', 'apazey_P1.cif', 'apazic_P1.cif', 'apuzuj_P1.cif', 'aqucog_P1.cif', 'aqudib_P1.cif', 'aradee_P1_charged.cif', 'arajek_P1.cif', '
# ...

# %%
refcodes = []
with open('refcodes.gcd', 'w') as f:
    for i in dir_list:
        split = i.split("_")[0]
        UC = split.upper()
        refcodes.append(UC)
        f.write('{}\n'.format(UC))

# %%
print(refcodes)
# Out:
# ['abadug', 'abedeu', 'abelom01', 'abexen', 'acemee', 'acenif', 'aciboe', 'acipip', 'acodon', 'acolub', 'acufek', 'acuruo', 'adabak01', 'adasij', 'adatac', 'adatik', 'adegey', 'adipai', 'adujer', 'aduwon', 'afadan', 'afitit', 'afukap', 'agofej', 'agovid', 'ahafar', 'aheqah', 'ahujev', 'ajakon', 'akayiv', 'akekin', 'akojao', 'alahus', 'alajop01', 'alecay', 'alejei', 'alejim', 'alicii', 'alixid', 'aludix', 'amilue', 'anugia', 'anugum', 'apazey', 'apazic', 'apuzuj', 'aqucog', 'aqudib', 'aradee', 'arajek', 'arajio', 'arajou', 'arakah', 'arazol', 'arofap', 'arohoh', 'aroqab', 'asinex', 'asinib', 'atajai', 'ateyop', 'ateyuv', 'atezac', 'atobiw', 'aturis', 'avajue02', 'avakal02', 'avakep02', 'avebub', 'aveqid', 'avesol', 'avihiy', 'avihoe', 'avudax', 'avujaf', 'avujuz', 'avukek', 'avupep', 'avuyey', 'awasey', 'awatav', 'awexux', 'axinax01', 'axinif', 'axoyuk', 'axukub', 'axulai', 'axuvib', 'ayoqem', 'azekic', 'azekoi', 'azuhub', 'azujaj', 'azujir', 'azujox', 'badxuc', 'badzak', 'baghea', 'ba
# ...
